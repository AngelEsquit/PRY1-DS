# %% [markdown]
# # 00. Descarga de datos crudos
#
# Esta etapa queda reservada para automatizar la obtención de los archivos fuente y dejar los `.xls` originales en `Data/raw/`; ninguna transformación debe ocurrir aquí.

# %%
print("Paso 0 reservado: todavía no se ha implementado la descarga automática.")
print("Cuando esté lista, aquí se dejarán los archivos .xls originales en Data/raw/")
# Out:
# Paso 0 reservado: todavía no se ha implementado la descarga automática.
# Cuando esté lista, aquí se dejarán los archivos .xls originales en Data/raw/

# %% [markdown]
# Al terminar, verifica que cada archivo conserve la extensión `.xls`. El siguiente notebook los detecta automáticamente, por lo que no se mantiene una lista manual de departamentos.
